# %%
import pandas as pd

# %%
# !ls
# Out:
# 0202_GoogleColab-1549119762873.ipynb   mobile_cleaned-1549119762886.csv
# 0202_PythonBasics-1549119762879.ipynb  Pandas.ipynb

# %%
df=pd.read_csv('mobile_cleaned-1549119762886.csv')
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
df.tail()
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 104         3        10        14   192.0            540                  1.8
# 105         0         5         3   157.0            400                  2.3
# 106         3        10         6   192.0            384                  1.8
# 107         3        10        12   129.0            250                  1.4
# 108         2         8         3   158.0            400                  2.2
#
#      thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 104        9.4           2                      2.0           2  ...
# 105        7.7           5                      5.0           3  ...
# 106        7.3           2                      5.0           3  ...
# 107        6.9           2                      1.2           3  ...
# 108        7.4           6                      8.0           3  ...
#
#      micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir?

# %%
df_less=df[23:29]

# %%
dir(df_less)
# Out:
# ['FM',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
len(df)
# Out:
# 109

# %%
df.shape
# Out:
# (109, 40)

# %%
df.loc[3]
# Out:
# sim_type                                0.0
# aperture                                8.0
# gpu_rank                               55.0
# weight                                152.0
# stand_by_time                         385.0
# processor_frequency                     1.3
# thickness                               8.0
# flash_type                              5.0
# front_camera_resolution                 2.0
# auto_focus                              3.0
# screen_size                             5.0
# frames_per_second                      15.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       0.0
# os                                      0.0
# phone_height                          147.5
# screen_protection                      26.0
# sim_size                                3.0
# price                                5799.0
# talk_time                              19.0
# video_resolution                      720.0
# ...

# %%
df_less.shape
# Out:
# (6, 40)

# %%
df_less
# Out:
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 23         3         1        43    97.0            345                  1.2
# 24         0        10        29   150.0            322                  1.5
# 25         0         8        43   202.0            914                  1.2
# 26         0         8        43   170.0            456                  1.2
# 27         0         8        38   155.0            350                  1.3
# 28         0         1        44   160.0            617                  1.7
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 23        5.1           5                      5.0           3  ...
# 24        8.2           5                      5.0           3  ...
# 25       10.6           2                      5.0           3  ...
# 26       10.8           2                      5.0           3  ...
# 27        9.3           5                      5.0           3  ...
# ...

# %%
df_thin=df[['stand_by_time','thickness','front_camera_resolution','is_liked']]

# %%
df_thin
# Out:
#      stand_by_time  thickness  front_camera_resolution  is_liked
# 0              250       10.5                     2.00         1
# 1              300       10.6                     0.30         1
# 2              329        8.5                     2.00         0
# 3              385        8.0                     2.00         1
# 4              385        7.9                     1.92         0
# ..             ...        ...                      ...       ...
# 104            540        9.4                     2.00         1
# 105            400        7.7                     5.00         1
# 106            384        7.3                     5.00         1
# 107            250        6.9                     1.20         1
# 108            400        7.4                     8.00         0
#
# [109 rows x 4 columns]

# %%
df_df=df_thin[0:10]

# %%
df_df
# Out:
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                     2.00         1
# 1            300       10.6                     0.30         1
# 2            329        8.5                     2.00         0
# 3            385        8.0                     2.00         1
# 4            385        7.9                     1.92         0
# 5            280        7.9                     5.00         0
# 6            230        8.8                     2.00         1
# 7            182        8.1                     2.00         1
# 8            182        8.2                     2.00         1
# 9            435       11.6                     2.00         1

# %%
df_df['is_liked'] == 1
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: is_liked, dtype: bool

# %%
df_d=df_df[df_df['is_liked'] == 1]

# %%
print(df_d)
# Out:
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                      2.0         1
# 1            300       10.6                      0.3         1
# 3            385        8.0                      2.0         1
# 6            230        8.8                      2.0         1
# 7            182        8.1                      2.0         1
# 8            182        8.2                      2.0         1
# 9            435       11.6                      2.0         1

# %%
df_df.mean()
# Out:
# stand_by_time              295.800
# thickness                    9.010
# front_camera_resolution      2.122
# is_liked                     0.700
# dtype: float64

# %%
df_df.describe()
# Out:
#        stand_by_time  thickness  front_camera_resolution   is_liked
# count      10.000000   10.00000                 10.00000  10.000000
# mean      295.800000    9.01000                  2.12200   0.700000
# std        87.551636    1.36337                  1.14249   0.483046
# min       182.000000    7.90000                  0.30000   0.000000
# 25%       235.000000    8.02500                  2.00000   0.250000
# 50%       290.000000    8.35000                  2.00000   1.000000
# 75%       371.000000   10.07500                  2.00000   1.000000
# max       435.000000   11.60000                  5.00000   1.000000

# %%
df_df[df_df['is_liked'] == 1]['thickness'].mean()
# Out:
# 9.4

# %%
s=df_df.groupby(['is_liked'])

# %%
for key,df_key in s:
    print(key)
    print(df_key)
# Out:
# 0
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 2            329        8.5                     2.00         0
# 4            385        7.9                     1.92         0
# 5            280        7.9                     5.00         0
# 1
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                      2.0         1
# 1            300       10.6                      0.3         1
# 3            385        8.0                      2.0         1
# 6            230        8.8                      2.0         1
# 7            182        8.1                      2.0         1
# 8            182        8.2                      2.0         1
# 9            435       11.6                      2.0         1

# %%
for key,df_key in s:
    print(key)
    print(df_key)
# Out:
# 0
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 2            329        8.5                     2.00         0
# 4            385        7.9                     1.92         0
# 5            280        7.9                     5.00         0
# 1
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                      2.0         1
# 1            300       10.6                      0.3         1
# 3            385        8.0                      2.0         1
# 6            230        8.8                      2.0         1
# 7            182        8.1                      2.0         1
# 8            182        8.2                      2.0         1
# 9            435       11.6                      2.0         1

# %%
s=df_less.groupby(['water_proof_rate'])

# %%
for key,dkey in s:
    print(key)
    print(dkey)
# Out:
# 2
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 23         3         1        43    97.0            345                  1.2
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 23        5.1           5                      5.0           3  ...
#
#     micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 23              2                    10                 2         68.1
#
#     expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 23                0.0        5         3              2000              94
#
#     is_liked
# 23         1
#
# [1 rows x 40 columns]
# 3
#     sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 28         0         1        44   160.0            617                  1.7
#
#     thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 28        9.6           5                      5.0           3  ...
#
# ...

# %%
df_df
# Out:
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                     2.00         1
# 1            300       10.6                     0.30         1
# 2            329        8.5                     2.00         0
# 3            385        8.0                     2.00         1
# 4            385        7.9                     1.92         0
# 5            280        7.9                     5.00         0
# 6            230        8.8                     2.00         1
# 7            182        8.1                     2.00         1
# 8            182        8.2                     2.00         1
# 9            435       11.6                     2.00         1

# %%
df_df.groupby(['is_liked']).mean()
# Out:
#           stand_by_time  thickness  front_camera_resolution
# is_liked
# 0            331.333333        8.1                 2.973333
# 1            280.571429        9.4                 1.757143

# %%
df_df.groupby(['is_liked']).describe()
# Out:
#          stand_by_time                                                     \
#                  count        mean        std    min    25%    50%    75%
# is_liked
# 0                  3.0  331.333333  52.538874  280.0  304.5  329.0  357.0
# 1                  7.0  280.571429  98.366419  182.0  206.0  250.0  342.5
#
#                 thickness       ...              front_camera_resolution  \
#             max     count mean  ...    75%   max                   count
# is_liked                        ...
# 0         385.0       3.0  8.1  ...   8.20   8.5                     3.0
# 1         435.0       7.0  9.4  ...  10.55  11.6                     7.0
#
#
#               mean       std   min   25%  50%  75%  max
# is_liked
# 0         2.973333  1.755601  1.92  1.96  2.0  3.5  5.0
# 1         1.757143  0.642540  0.30  2.00  2.0  2.0  2.0
#
# [2 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()

# %%
graph=sns.pairplot(df_df, diag_kind='hist')

# %%
graph=sns.pairplot(df_df, diag_kind='hist', hue='is_liked')

# %%
df_df
# Out:
#    stand_by_time  thickness  front_camera_resolution  is_liked
# 0            250       10.5                     2.00         1
# 1            300       10.6                     0.30         1
# 2            329        8.5                     2.00         0
# 3            385        8.0                     2.00         1
# 4            385        7.9                     1.92         0
# 5            280        7.9                     5.00         0
# 6            230        8.8                     2.00         1
# 7            182        8.1                     2.00         1
# 8            182        8.2                     2.00         1
# 9            435       11.6                     2.00         1
